# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
nama = "tassya"
seorang = 'mahasiswa'
universitas = 'udayana'
jurusan = 'matematika'
print(nama +  ' seorang '+ seorang + ' kuliah di '+ universitas + ' jurusan ' + jurusan +'.' )
# Out:
# tassya seorang mahasiswa kuliah di udayana jurusan matematika.

# %%
prodi= 'dia prodi matematika'
print(prodi[0:3])
print(prodi[0:-2])
print(prodi[3:-1])
print(prodi[2:-1:3])
print(prodi[:-5])
print(prodi[:])
# Out:
# dia
# dia prodi matemati
#  prodi matematik
# ariami
# dia prodi matem
# dia prodi matematika

# %%
tema = 'hidup sehat jalan sukses'
print(len(tema))
tema.upper()
tema.lower()
# Out:
# 24
# 'hidup sehat jalan sukses'

# %%
tema = 'hidup sehat jalan sukses'
tema.find('sehat')
# Out:
# 6

# %%
tema = 'hidup sehat jalan sukses'
tema.replace('hidup', 'dunia')
# Out:
# 'dunia sehat jalan sukses'

# %%
tema = 'hidup sehat jalan sukses'
print('hidup' in tema)
# Out:
# True

# %%
tema = 'hidup sehat jalan sukses'
print('Hidup' in tema)
# Out:
# False

# %%
print(119+2)
mangga = 20
manggis = 17
buah = mangga + manggis 
print(buah)
# Out:
# 121
# 37

# %%
pinjam = 500000
bayar = 10000
sisapinjam = pinjam - bayar
print("sisapinjam kamu adalah", sisapinjam)
# Out:
# sisapinjam kamu adalah 490000

# %%
panjang = 70
lebar = 19
luas = panjang * lebar
print(luas)
# Out:
# 1330

# %%
coklat = 20
siswa = 10
coklatpersiswa = coklat / siswa
print("setiap siswa akan mendapatkan bagian coklat ",coklatpersiswa)
# Out:
# setiap siswa akan mendapatkan bagian coklat  2.0

# %%
bilangan1 = 5000
bilangan2 = 2000
hasil = bilangan1 % bilangan2
print("sisa bagi dari bilangan ",bilangan1," dan ",bilangan2," adalah", hasil)
# Out:
# sisa bagi dari bilangan  5000  dan  2000  adalah 1000

# %%
y = 500>200
print(y)
y = 500<200
print(y)
y = 500 >= 200
print (y)
y = 500 <= 200
print(y)
y = 500 == 500
print(y)
y = 500 !=200
# Out:
# True
# False
# True
# False
# True

# %%
hewan_cicak = 200
hewan_kodok = 500
print(hewan_cicak > 10 and hewan_kodok < 30)
print(hewan_cicak < 10 or hewan_kodok < 30)
print(hewan_cicak > 100 and hewan_kodok < 600)
print( not (hewan_cicak < 100 or hewan_kodok > 600))
# Out:
# False
# False
# True
