# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np_34
import math

# import math
# diketahui x yang memenuhi x**2+x-1 
# menentukan nilai dari n yang memenuhi persamaan x**2024 - x**2025 = (x(1-x))**n
print("x^2024-x^2025 = (x(1-x))^n")
print()
#jika di ketahui 
a_34 = 1
b_34 = 1
c_34 = -1
print ("yang pertama kita lakukan adalah menghitung nilai persamaan kuadrat nya dengan rumus (-b ± √(b^2-(4*a*c))) / 2*a') ")
print (" kita memasukkan nilai a,b,c kedalam  persamaan kuadrat nya sehingga")
x1_34 = -1.618033988749895
x2_34 =  0.6180339887498949

print ("diketahui n = log(x^2024*x^2025)/log(x(1-x))")
print("kita ubah menjadi log(x^2024)+log(1-x)") 


if x1_34 == -1.618033988749895:
     x1_34 = (-1 + (np_34.sqrt(5))) / 2
     d_34 = 2024 * np_34.log(x1_34) + np_34.log(1 - x1_34)
     e_34 = x1_34 * (1 - x1_34)
     positif_34 = d_34 / np_34.log(np_34.abs(e_34))
     print(f"Nilai n yang memenuhi: {positif_34}")
     print('')
    
       
elif x1_34 == 0.6180339887498949:
    x1_34 = (-1 + (np_34.sqrt(5))) / 2
    d_34 = 2024 * np.log(x1_34) + np_34.log(1 - x1_34)
    e_34 = x1_34 * (1 - x1_34)
    positif_34 = d_34 / np_34.log(np_34.abs(e_34))
    print(f"Nilai n yang memenuhi: {negatif_34}")
    print('')
else :
    print("Harap masukkan nilai yang benar")
# Out:
# x^2024-x^2025 = (x(1-x))^n
#
# yang pertama kita lakukan adalah menghitung nilai persamaan kuadrat nya dengan rumus (-b ± √(b^2-(4*a*c))) / 2*a')
#  kita memasukkan nilai a,b,c kedalam  persamaan kuadrat nya sehingga
# diketahui n = log(x^2024*x^2025)/log(x(1-x))
# kita ubah menjadi log(x^2024)+log(1-x)
# Nilai n yang memenuhi: 675.3333333333333
