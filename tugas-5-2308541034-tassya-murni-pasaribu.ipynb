# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#2.15
print("Berat badan prodi biologi angkatan 2023")
berat_badan_34 =[50,70,55,45]
terberat = berat_badan_34[0]
for i in range (len(berat_badan_34)):
    if berat_badan_34[i] > terberat:
        terberat = berat_badan_34 [i]
print(terberat)
# Out:
# Berat badan prodi biologi angkatan 2023
# 70

# %%
#2.16
matrik_34 = [
    [15,16,22,14,13],
    [6,8,10,3,5,4],
    [22,23,17,16,21],
    [12,24,15,7]
]
print(matrik_34 [0])
print(matrik_34 [1][2])
print(matrik_34)
# Out:
# [15, 16, 22, 14, 13]
# 10
# [[15, 16, 22, 14, 13], [6, 8, 10, 3, 5, 4], [22, 23, 17, 16, 21], [12, 24, 15, 7]]

# %%
#2.16

matrik_34 = [
    [15,16,22,14,13],
    [6,8,10,3,5,4],
    [22,23,17,16,21],
    [12,24,15,7]
]
for baris in matrik_34:
    print(baris)
    for kolom in baris:
        print(kolom)
# Out:
# [15, 16, 22, 14, 13]
# 15
# 16
# 22
# 14
# 13
# [6, 8, 10, 3, 5, 4]
# 6
# 8
# 10
# 3
# 5
# 4
# [22, 23, 17, 16, 21]
# 22
# 23
# 17
# 16
# 21
# [12, 24, 15, 7]
# 12
# 24
# 15
# 7

# %%
#2.17
prodi_34 = ('arsitektur','matematika','biologi','mesin','elektro','fisika')
print(prodi_34[3])
print(prodi_34[1:4])
for isi in prodi_34[0:5]:
    print(isi)
print(" ")
prodi_34.index('mesin')
print(prodi_34.index('mesin'))
prodi_34.count('matematika')
print(prodi_34.count('mesin'))
# Out:
# mesin
# ('matematika', 'biologi', 'mesin')
# arsitektur
# matematika
# biologi
# mesin
# elektro
#
# 3
# 1

# %%
#2.18

interview_34 = ("Hari ini saya akan pergi ke perusahaan tekstil untuk melakukan interview yang telah ditentuin oleh HRD bahwa jadwal interviewnya hari ini. Pada saat interview saya ditanya mengenai data diri saya yaitu:")
print(interview_34)
data_diri_34 ={
    "nama" : "Nama saya Tasya Murni Pasaribu",
    "umur" : 'usia saya 19',
    "apakah_singel" : 'yeah, saya singel'
}
print(data_diri_34 ["nama"])
print(data_diri_34 ["umur"])
print(data_diri_34 ["apakah_singel"])
# Out:
# Hari ini saya akan pergi ke perusahaan tekstil untuk melakukan interview yang telah ditentuin oleh HRD bahwa jadwal interviewnya hari ini. Pada saat interview saya ditanya mengenai data diri saya yaitu:
# Nama saya Tasya Murni Pasaribu
# usia saya 19
# yeah, saya singel

# %%
#2.19
def full_name(first_name_34, last_name_34, nick_name_34):
    print(f"nama lengkapnya adalah {nama_depan} {nama_belakang} {nama_pangilan}")

print("Saya memiliki seseorang yang saya suka secara diam")
print("saya menyukainya sejak SMP, hingga masuk SMA. Kami satu sekolah walaupun beda kelas")
print("saya sering memperhatikan dia ketika melihatnya")
print("suatu hari saya memberani untuk mengobrol dengannya")
print("diapun memberitahu seputar nama lengkapnya. Walaupun sebenarnya saya sudah tau dari lama siapa namanya, tapi saya sangat senang ketika dia sendiri yang memperkenalkan diri")

first_name_34 = input("Nama depannya adalah")
last_name_34 = input("Nama belakangnya")
nick_name_34 = input("biasa dipanggil")
# Out:
# Saya memiliki seseorang yang saya suka secara diam
# saya menyukainya sejak SMP, hingga masuk SMA. Kami satu sekolah walaupun beda kelas
# saya sering memperhatikan dia ketika melihatnya
# suatu hari saya memberani untuk mengobrol dengannya
# diapun memberitahu seputar nama lengkapnya. Walaupun sebenarnya saya sudah tau dari lama siapa namanya, tapi saya sangat senang ketika dia sendiri yang memperkenalkan diri
# Nama depannya adalah Alaska
# Nama belakangnya Dewandaru
# biasa dipanggil Dewa
